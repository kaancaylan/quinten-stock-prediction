# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data_finance.csv", delimiter=";").iloc[:, 1:]
# Out:
# /var/folders/3x/b7p1txv95nl6qm0pnzz_d2ch0000gn/T/ipykernel_98689/658980649.py:1: DtypeWarning: Columns (6,8,16,17,26,33,34,66,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,252,253,255,257,259,261,263,265,267,269,270,271,272,273,274,275,276,277,278,279,280,284,285,286,290) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("raw_data_finance.csv", delimiter=";").iloc[:, 1:]

# %%
(df.isna().sum() / len(df)).sort_values()
# Out:
# symbol                    0.000000
# year                      0.000000
# quarter                   0.000000
# date                      0.000000
# week                      0.000000
#                             ...
# estimatedEbitdaAvg        0.947932
# estimatedEbitLow          0.947932
# estimatedEbitHigh         0.947932
# estimatedNetIncomeHigh    0.947932
# estimatedEbitAvg          0.947932
# Length: 290, dtype: float64

# %%
df.estimatedSgaExpenseLow.isna().sum()/ len(df.estimatedSgaExpenseLow)
# Out:
# 0.9479317299642286

# %% [markdown]
# # Make date and symbol index

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.set_index(["symbol", "date"], inplace=True)

# %%
df.groupby(level=0).apply(lambda x:x.isna().sum()/ len(x))
# Out:
#           year  quarter  week  acceptedDate  calendarYear       cik  \
# symbol
# 0O9.F      0.0      0.0   0.0      0.883929      0.883929  0.883929
# 0QF.F      0.0      0.0   0.0      0.893805      0.893805  0.893805
# 217A.F     0.0      0.0   0.0      0.681416      0.681416  0.681416
# 22UA.F     0.0      0.0   0.0      0.797386      0.797386  0.797386
# 2CRSI.PA   0.0      0.0   0.0      1.000000      1.000000  1.000000
# ...        ...      ...   ...           ...           ...       ...
# XIOR.BR    0.0      0.0   0.0      0.954887      0.954887  0.954887
# YATRA.AS   0.0      0.0   0.0      0.526786      0.526786  0.526786
# YK6B.F     0.0      0.0   0.0      1.000000      1.000000  1.000000
# ZEL.NZ     0.0      0.0   0.0      1.000000      1.000000  1.000000
# ZEN.BR     0.0      0.0   0.0      1.000000      1.000000  1.000000
#
#           costAndExpenses  costOfRevenue  depreciationAndAmortization  \
# symbol
# 0O9.F            0.883929       0.883929                     0.883929
# 0QF.F            0.893805       0.893805                     0.893805
# 217A.F           0.681416       0.681416                     0.681416
# 22UA.F           0.797386       0.797386                     0.797386
# 2CRSI.PA         1.000000       1.000000                     1.000000
# ...                   ...            ...                          ...
# XIOR.BR          0.954887       0.954887                     0.954887
# YATRA.AS         0.526786       0.526786                     0.526786
# YK6B.F           1.000000       1.000000                     1.000000
# ZEL.NZ           1.000000       1.000000                     1.000000
# ZEN.BR           1.000000       1.000000                     1.000000
#
#             ebitda  ...  estimatedRevenueAvg  estimatedRevenueHigh  \
# symbol              ...
# 0O9.F     0.883929  ...                  1.0                   1.0
# 0QF.F     0.893805  ...                  1.0                   1.0
# 217A.F    0.681416  ...                  1.0                   1.0
# 22UA.F    0.797386  ...                  1.0                   1.0
# 2CRSI.PA  1.000000  ...                  1.0                   1.0
# ...            ...  ...                  ...                   ...
# XIOR.BR   0.954887  ...                  1.0                   1.0
# YATRA.AS  0.526786  ...                  1.0                   1.0
# YK6B.F    1.000000  ...                  1.0                   1.0
# ZEL.NZ    1.000000  ...                  1.0                   1.0
# ZEN.BR    1.000000  ...                  1.0                   1.0
#
#           estimatedRevenueLow  estimatedSgaExpenseAvg  \
# symbol
# 0O9.F                     1.0                     1.0
# 0QF.F                     1.0                     1.0
# 217A.F                    1.0                     1.0
# 22UA.F                    1.0                     1.0
# 2CRSI.PA                  1.0                     1.0
# ...                       ...                     ...
# XIOR.BR                   1.0                     1.0
# YATRA.AS                  1.0                     1.0
# YK6B.F                    1.0                     1.0
# ZEL.NZ                    1.0                     1.0
# ZEN.BR                    1.0                     1.0
#
#           estimatedSgaExpenseHigh  estimatedSgaExpenseLow  \
# symbol
# 0O9.F                         1.0                     1.0
# 0QF.F                         1.0                     1.0
# 217A.F                        1.0                     1.0
# 22UA.F                        1.0                     1.0
# 2CRSI.PA                      1.0                     1.0
# ...                           ...                     ...
# XIOR.BR                       1.0                     1.0
# YATRA.AS                      1.0                     1.0
# YK6B.F                        1.0                     1.0
# ZEL.NZ                        1.0                     1.0
# ZEN.BR                        1.0                     1.0
#
#           numberAnalystEstimatedRevenue  numberAnalystsEstimatedEps     close  \
# symbol
# 0O9.F                               1.0                         1.0  0.883929
# 0QF.F                               1.0                         1.0  0.876106
# 217A.F                              1.0                         1.0  0.814159
# 22UA.F                              1.0                         1.0  0.673203
# 2CRSI.PA                            1.0                         1.0  0.776000
# ...                                 ...                         ...       ...
# XIOR.BR                             1.0                         1.0  0.691729
# YATRA.AS                            1.0                         1.0  0.821429
# YK6B.F                              1.0                         1.0  0.955357
# ZEL.NZ                              1.0                         1.0  0.821429
# ZEN.BR                              1.0                         1.0  0.830357
#
#             volume
# symbol
# 0O9.F     0.883929
# 0QF.F     0.876106
# 217A.F    0.814159
# 22UA.F    0.673203
# 2CRSI.PA  0.776000
# ...            ...
# XIOR.BR   0.691729
# YATRA.AS  0.821429
# YK6B.F    0.955357
# ZEL.NZ    0.821429
# ZEN.BR    0.830357
#
# [1407 rows x 288 columns]

# %%
df.loc["22UA.F"].sort_index().isna().all(axis=1).value_counts()
# Out:
# False    153
# dtype: int64
