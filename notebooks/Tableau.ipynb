# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import preprocessing as pr
import plotly.express as px

# %%
cd src/data/
# Out:
# [WinError 3] The system cannot find the path specified: 'src/data/'
# c:\Users\Rehan Ibrahim\OneDrive - HEC Paris\Desktop\quinten-stock-prediction\src\data

# %%
df = pr.get_data()
# Out:
# c:\Users\Rehan Ibrahim\OneDrive - HEC Paris\Desktop\quinten-stock-prediction\src\data\preprocessing.py:7: DtypeWarning: Columns (8,17,26,33,34,66,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,252,253,255,257,259,261,263,265,267,269,270,271,272,273,274,275,276,277,278,279,280,284,285,286,290) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, delimiter=";", parse_dates=date_cols).iloc[:, 1:]

# %%
df.head()
# Out:
#                      year  quarter  week acceptedDate  calendarYear  \
# date       symbol
# 1995-01-31 0O9.F     1995        1     5          NaT           NaN
#            0QF.F     1995        1     5          NaT           NaN
#            217A.F    1995        1     5          NaT           NaN
#            22UA.F    1995        1     5          NaT           NaN
#            2CRSI.PA  1995        1     5          NaT           NaN
#
#                      costAndExpenses  costOfRevenue  \
# date       symbol
# 1995-01-31 0O9.F                 NaN            NaN
#            0QF.F                 NaN            NaN
#            217A.F                NaN            NaN
#            22UA.F                NaN            NaN
#            2CRSI.PA              NaN            NaN
#
#                      depreciationAndAmortization  ebitda  ebitdaratio  ...  \
# date       symbol                                                      ...
# ...

# %%
# Convert the index to a regular column, remove duplicates, and set the index again
df_unique = df.reset_index().drop_duplicates(subset=['symbol', 'date']).set_index(['symbol', 'date'])

# Now to get the data for a specific symbol:
symbol_data = df_unique.loc['2CRSI.PA'].reset_index()


import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame and it has been loaded with your data
# df = pd.read_csv('your_data.csv', parse_dates=['date'])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(symbol_data['date'],symbol_data['close'], label='Price', color='blue')  # or df['close'] if 'price' column is not available
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_unique = df_unique[-df_unique['close'].isna()]

# %%
df_unique.shape
# Out:
# (25798, 286)

# %%
df_unique.to_csv('tableau_dataset1.csv')

# %%
symbol_data.head()
# Out:
#             year  quarter  week acceptedDate  calendarYear  costAndExpenses  \
# date
# 1995-01-31  1995        1     5          NaT           NaN              NaN
# 1995-03-31  1995        3    13          NaT           NaN              NaN
# 1995-06-30  1995        6    26          NaT           NaN              NaN
# 1995-09-30  1995        9    39          NaT           NaN              NaN
# 1996-01-31  1996        1     5          NaT           NaN              NaN
#
#             costOfRevenue  depreciationAndAmortization  ebitda  ebitdaratio  \
# date
# 1995-01-31            NaN                          NaN     NaN          NaN
# 1995-03-31            NaN                          NaN     NaN          NaN
# 1995-06-30            NaN                          NaN     NaN          NaN
# 1995-09-30            NaN                          NaN     NaN          NaN
# 1996-01-31            NaN                          NaN     NaN          NaN
#
# ...

# %%
symbol_data.reset_index(inplace=True)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame and it has been loaded with your data
# df = pd.read_csv('your_data.csv', parse_dates=['date'])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(symbol_data['date'],symbol_data['close'], label='Price', color='blue')  # or df['close'] if 'price' column is not available
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['ROI'] = (df['capitalExpenditure']/df['netIncome']) * 100

# %%
def calculate_eps(net_income, weighted_average_shs_out):
    # Use the .replace method to replace 0 with NaN to avoid division by zero
    weighted_average_shs_out_replaced = weighted_average_shs_out.replace(0, np.nan)
    # Now perform element-wise division
    eps = net_income / weighted_average_shs_out_replaced
    return eps

# Call the function
eps = calculate_eps(df['netIncome'], df['weightedAverageShsOut'])
df['eps'] = eps

# %%
import pandas as pd
import numpy as np  # Import numpy for handling NaN values

# Assuming df is your DataFrame
# Replace zeros with NaN to avoid division by zero errors
df['revenue'] = df['revenue'].replace(0, np.nan)
# Calculate profit margin
df['profit_margin'] = (df['netIncome'] / df['revenue']) * 100

# %%
import pandas as pd
import numpy as np  # Import numpy to handle NaN values

# Assuming df is your DataFrame
# Replace zeros with NaN to avoid division by zero errors
df['weightedAverageShsOut'] = df['weightedAverageShsOut'].replace(0, np.nan)
df['eps'] = df['eps'].replace(0, np.nan)  # Assuming eps is a column in your DataFrame

# Perform vectorized operations to calculate the Market Value Per Share and PE Ratio
df['market_value_per_share'] = df['marketCapitalization'] / df['weightedAverageShsOut']
df['pe_ratio'] = df['market_value_per_share'] / df['eps']

# %%
df.head()
# Out:
#                      year  quarter  week acceptedDate  calendarYear  \
# date       symbol
# 1995-01-31 0O9.F     1995        1     5          NaT           NaN
#            0QF.F     1995        1     5          NaT           NaN
#            217A.F    1995        1     5          NaT           NaN
#            22UA.F    1995        1     5          NaT           NaN
#            2CRSI.PA  1995        1     5          NaT           NaN
#
#                      costAndExpenses  costOfRevenue  \
# date       symbol
# 1995-01-31 0O9.F                 NaN            NaN
#            0QF.F                 NaN            NaN
#            217A.F                NaN            NaN
#            22UA.F                NaN            NaN
#            2CRSI.PA              NaN            NaN
#
#                      depreciationAndAmortization  ebitda  ebitdaratio  ...  \
# date       symbol                                                      ...
# ...

# %%
# Plotting
fig = px.line(df, x=df.index, y='price', title='Stock Price Over Time')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Price')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Rehan Ibrahim\OneDrive - HEC Paris\Desktop\quinten-stock-prediction\notebooks\Tableau.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Plotting
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> fig = px.line(df, x=df.index, y='price', title='Stock Price Over Time')
#       <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> fig.update_xaxes(title_text='Date')
# ...

# %%
df['clso']

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame and it has been loaded with your data
# df = pd.read_csv('your_data.csv', parse_dates=['date'])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['quarter'], df['close'], label='Price', color='blue')  # or df['close'] if 'price' column is not available
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Rehan Ibrahim\OneDrive - HEC Paris\Desktop\quinten-stock-prediction\notebooks\Tableau.ipynb Cell 12 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> # Assuming df is your DataFrame and it has been loaded with your data
#       <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> # df = pd.read_csv('your_data.csv', parse_dates=['date'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Rehan%20Ibrahim/OneDrive%20-%20HEC%20Paris/Desktop/quinten-stock-prediction/notebooks/Tableau.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>
# ...
